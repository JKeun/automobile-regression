# %%
import pandas as pd

df = pd.read_csv("../data/autos.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  wheel-base  length  width  height  curb-weight engine-type num-of-cylinders  \
# 0          3                 ?  alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four
# 1          3                 ?  alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four
# 2          1                 ?  alfa-romero       gas        std          two    hatchback          rwd           front        94.5   171.2   65.5    52.4         2823        ohcv              six
# 3          2               164         audi       gas        std         four        sedan          fwd           front        99.8   176.6   66.2    54.3         2337         ohc             four
# 4          2               164         audi       gas        std         four        sedan          4wd           front        99.4   176.6   66.4    54.3         2824         ohc             five
#
#    engin-size fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 0         130        mpfi  3.47   2.68                9.0        111     5000        21           27  13495
# 1         130        mpfi  3.47   2.68                9.0        111     5000        21           27  16500
# 2         152        mpfi  2.68   3.47                9.0        154     5000        19           26  16500
# 3         109        mpfi  3.19   3.40               10.0        102     5500        24           30  13950
# 4         136        mpfi  3.19   3.40                8.0        115     5500        18           22  17450

# %%
# remove syboling feature  & samples having mv in target
df = df.drop("symboling", axis=1)
df.head()
# Out:
#   normalized-losses         make fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  wheel-base  length  width  height  curb-weight engine-type num-of-cylinders  engin-size  \
# 0                 ?  alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four         130
# 1                 ?  alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four         130
# 2                 ?  alfa-romero       gas        std          two    hatchback          rwd           front        94.5   171.2   65.5    52.4         2823        ohcv              six         152
# 3               164         audi       gas        std         four        sedan          fwd           front        99.8   176.6   66.2    54.3         2337         ohc             four         109
# 4               164         audi       gas        std         four        sedan          4wd           front        99.4   176.6   66.4    54.3         2824         ohc             five         136
#
#   fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 0        mpfi  3.47   2.68                9.0        111     5000        21           27  13495
# 1        mpfi  3.47   2.68                9.0        111     5000        21           27  16500
# 2        mpfi  2.68   3.47                9.0        154     5000        19           26  16500
# 3        mpfi  3.19   3.40               10.0        102     5500        24           30  13950
# 4        mpfi  3.19   3.40                8.0        115     5500        18           22  17450

# %%
pd.to_numeric(df['normalized-losses'], errors="coerce")
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      164.0
# 4      164.0
# 5        NaN
# 6      158.0
# 7        NaN
# 8      158.0
# 9        NaN
# 10     192.0
# 11     192.0
# 12     188.0
# 13     188.0
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18     121.0
# 19      98.0
# 20      81.0
# 21     118.0
# 22     118.0
# 23     118.0
# 24     148.0
# 25     148.0
# 26     148.0
# 27     148.0
# 28     110.0
# 29     145.0
#        ...
# 175     65.0
# 176     65.0
# 177     65.0
# 178    197.0
# 179    197.0
# 180     90.0
# 181      NaN
# 182    122.0
# 183    122.0
# 184     94.0
# 185     94.0
# 186     94.0
# 187     94.0
# 188     94.0
# 189      NaN
# 190    256.0
# 191      NaN
# 192      NaN
# 193      NaN
# 194    103.0
# 195     74.0
# 196    103.0
# 197     74.0
# 198    103.0
# 199     74.0
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, dtype: float64
